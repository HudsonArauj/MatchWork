# %%
##### LLAMAPARSE #####
from llama_parse import LlamaParse
from dotenv import load_dotenv

from groq import Groq
from langchain_groq import ChatGroq

from src.schemas import Topics, Subjetivas

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

import os

import nest_asyncio  # noqa: E402
nest_asyncio.apply()

load_dotenv()
# Out:
# True

# %%
from src.utils import generate_questions, generate_profile
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# %%
import random

from uuid import uuid4
from langchain_core.documents import Document

# %%
personalities = ["supportive, calm, and patient", "confident, assertive, and competitive", "creative, imaginative, and innovative", "analytical, logical, and detail-oriented", "enthusiastic, outgoing, and energetic", "organized, efficient, and reliable", "friendly, warm, and approachable", "diplomatic, tactful, and respectful", "adaptable, flexible, and open-minded", "independent, self-motivated, and goal-oriented"]

base_path = "data/curriculos/"

documents = []

for curr in os.listdir(base_path):

    path = base_path+ curr

    questions = generate_questions(path)
    questions = [q[1] for q in questions]
    # print(questions)
    # break
    answer_prompt = [("system", 
                    "You are a candidate for a job position. You have to answer the following questions based on your profile: {questions}"),
                    ("system", f"You are a candidate that is {random.choice(personalities)}"),
                    ("system", "Your answers must depict your personality and skills.")]
    
    answer_template = ChatPromptTemplate(answer_prompt)

    output_parser = StrOutputParser()

    openai = ChatOpenAI(
        api_key=os.getenv("OPENAI_API_KEY"),
        model = "gpt-4o-mini",
        temperature=random.randrange(10, 20)/100,
    )

    embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

    chain = answer_template | openai | output_parser

    responses = chain.invoke({"questions": "\n".join(questions)})

    documents.append(Document(page_content = responses, metadata={"source": path}))

print(len(documents))
# Out:
# Started parsing the file under job_id ad64f9ce-9039-4f1b-b30b-ddb0c7ac53cf
# Started parsing the file under job_id 3ba5c501-506e-41d4-a3e6-7bea350d0b96
# Started parsing the file under job_id 12ff89ac-108e-4785-8b0b-98ae13a30549
# Started parsing the file under job_id 39250661-f2f7-483f-812f-85aa90047997
# Started parsing the file under job_id f77b779e-f436-43f2-b670-9c0d18017704
# Started parsing the file under job_id c54adc68-b4ef-4570-a35e-eabdc2ce63fc
# Started parsing the file under job_id c138e691-cc23-4a5a-85ce-1155570dfa75
# Started parsing the file under job_id f17443f5-5866-4566-88b3-7c0c6bd21a16
# Started parsing the file under job_id 34972cd3-0b06-4bc4-b38e-83cd7cbcc922
# Started parsing the file under job_id 8aee17c1-7f00-4293-af8e-744a81bf085b
# Started parsing the file under job_id f6086319-5072-4926-b249-df25228a003f
# Started parsing the file under job_id ff2d3633-cc59-4974-b0c9-5a5dba9ab05c
# Started parsing the file under job_id fdb3584d-cbd1-420b-b334-85dc22c5c965
# Started parsing the file under job_id 14b3e10c-6bc5-4a55-9706-4bd4f3f73f24
# Started parsing the file under job_id d3fd5811-db5a-4096-8962-8819d320323d
# Started parsing the file under job_id 5a0d0f3f-0730-4f01-b788-5e12413ab29c
# Started parsing the file under job_id b19836cd-a8db-43a5-b63f-0774cefb3a8f
# Started parsing the file under job_id 7aeb8ee5-298b-440e-bad1-17bf1b4bcc3b
# Started parsing the file under job_id a4be62b0-60ba-4e25-b5dd-441079867de2
# Started parsing the file under job_id 8bdf3c15-eecf-4d40-ad9f-00e631f7cba3
# Started parsing the file under job_id 6f02c9fc-5432-4755-b78c-a507631c494a
# Started parsing the file under job_id 5bf98a00-a468-4a46-9e36-1d7a1ff47c66
# Started parsing the file under job_id 327ed333-216f-48fb-b9f5-598a78fb7779
# Started parsing the file under job_id d0d4f56b-096a-4e6c-9c0c-f80bd0f2ccd0
# Started parsing the file under job_id 262d2ba3-bac7-4013-87cd-f74d07cf5fe8
# Started parsing the file under job_id 7f187f33-a5c3-4dbd-84e2-31b835da2022
# Started parsing the file under job_id c840b78f-571a-4e87-aa7e-79470310a9a4
# Started parsing the file under job_id 247f34ce-3c1c-438c-b6b6-83c4c48b4386
# Started parsing the file under job_id d562381c-1fa0-401a-bd87-7d763d75be8b
# Started parsing the file under job_id 3e1ccc9f-8352-4e03-a908-56d24c309c5d
# Started parsing the file under job_id 95dcb6c9-9bf5-4fbf-a9e2-c0e06edb248c
# Started parsing the file under job_id e8579181-6776-4533-a0f7-e4148dca33ee
# Started parsing the file under job_id fbdfe8a3-2b3b-4076-89ad-c0e26ef43cc1
# Started parsing the file under job_id 6e7cb2d5-0e82-4e48-9cab-b5851f1188fd
# Started parsing the file under job_id be97a0d2-ad70-46aa-822a-47ad59c08ad5
# Started parsing the file under job_id b1204665-bc42-4a1d-a682-9b3f83e4d33d
# Started parsing the file under job_id 002ea2cc-e278-4249-a1af-3fd45cebc1ab
# Started parsing the file under job_id 6c6de314-65bd-44ca-a483-2578654ffb1b
# Started parsing the file under job_id da4db486-6893-4d5c-ae71-2f0c04030223
# Started parsing the file under job_id b709af10-311a-4e13-bdba-0760c404df3f
# Started parsing the file under job_id 56ce145b-f369-4544-904e-7a9e57cba5a0
# Started parsing the file under job_id 2342e595-8e2f-4c21-8f44-f056d1b74f84
# Started parsing the file under job_id ba3ec90e-c811-426a-8da5-688ebbaed699
# Started parsing the file under job_id e836591d-1ae2-4df3-b07b-1efe30e2e1af
# Started parsing the file under job_id 673a104a-91be-4329-8d32-b84b021d51af
# Started parsing the file under job_id 61db1923-0d2e-459f-bfb8-0d3ebb79c538
# Started parsing the file under job_id 06833d08-5621-4383-a3ec-947fbd08f5da
# Started parsing the file under job_id 81c6ccb1-39f2-4c34-9c6f-b33c92ffb7a3
# Started parsing the file under job_id db6c9618-ce86-4ff6-b85d-ea28dcda8bba
# Started parsing the file under job_id 6a43cd5d-07f7-498e-82bc-665065508141
# Started parsing the file under job_id a4f9224c-0cc1-4b82-9c80-3ecab092ca23
# Started parsing the file under job_id fd0c43f9-4c93-4625-a41a-6f00ccaa4b63
# Started parsing the file under job_id d262f210-ad24-4b35-bece-11a9692d9793
# Started parsing the file under job_id a4055316-9e0e-492d-8d85-8aca3097706e
# Started parsing the file under job_id 3975e8cc-fef1-4fc8-9a6e-40cd1fccb763
# Started parsing the file under job_id fa34d21b-08b6-4c85-a6b9-6332d25d4e56
# Started parsing the file under job_id c84b1956-2107-44f5-8323-48b2b011eece
# Started parsing the file under job_id 4a29a9f3-52a1-4023-b59e-4e12691541f4
# Started parsing the file under job_id 66f6b6e4-4acd-4ac3-bdaf-1bb376242aa4
# Started parsing the file under job_id aeae7eae-6e77-47d4-b0b2-99fef67adda9
# Started parsing the file under job_id 77c56129-b1fb-45c2-af13-f1a7e0f026f1
# Started parsing the file under job_id 638d7d9e-bda5-4985-b301-0153e43dedc5
# Started parsing the file under job_id e6ec9c1c-85c8-4838-91c5-943eac04f3d5
# Started parsing the file under job_id 98d1b268-96c0-4451-988a-a4c82aad6e68
# Started parsing the file under job_id 0edadf79-7e18-4491-b791-8ac70668a144
# Started parsing the file under job_id 1d9651be-c307-4104-aeb0-78d50f1d76db
# Started parsing the file under job_id cd961140-e176-4eaf-9443-05ef467f7c10
# Started parsing the file under job_id 9ee7dca0-8818-48ba-9cfb-a4716de61faf
# Started parsing the file under job_id 15b28890-b522-4542-a5ed-d2373c136d77
# Started parsing the file under job_id 7df4ac6b-8524-4a1f-a4a9-cf2459f1d52f
# Started parsing the file under job_id 39b0a790-a57c-40f3-befb-7e988f16f9e0
# Started parsing the file under job_id 888eafce-79f9-48c6-91b5-2a93872b6a97
# Started parsing the file under job_id 582441ae-2f2b-4663-a27c-6aa41b0c9cc8
# Started parsing the file under job_id fe3f9e67-92f8-4a34-9939-867777be813f
# Started parsing the file under job_id 66014b37-2fb4-4b7b-bbac-701c2a13c832
# 75

# %%
# %pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.9.0-cp310-cp310-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\talinho\onedrive - insper - institudo de ensino e pesquisa\área de trabalho\llamahackhaton\matchwork\.venv\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\talinho\onedrive - insper - institudo de ensino e pesquisa\área de trabalho\llamahackhaton\matchwork\.venv\lib\site-packages (from faiss-cpu) (23.2)
# Using cached faiss_cpu-1.9.0-cp310-cp310-win_amd64.whl (14.9 MB)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

index = faiss.IndexFlatL2(len(embeddings.embed_query("hello world")))

vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

uuids = [str(uuid4()) for _ in range(len(documents))]

vector_store.add_documents(documents=documents, ids=uuids)
# Out:
# ['cb634a38-4ce9-4610-b936-c353c243ae97',
#  'd5d3b620-7e72-4ec9-b585-765b6b05fd2e',
#  'a633e02c-deda-40bf-addc-17fbdbda7f70',
#  '25b49986-3977-42f2-aa01-97359b9b1edc',
#  'f2b523ae-d00d-4787-8e39-d35307407121',
#  '405d0ad3-102c-4bec-a321-c13c783b0e72',
#  '42cce91b-7475-4ae5-b62c-ecba62143439',
#  '4a3a056c-6d7b-4351-99bb-cbbc482d1142',
#  '9fff4f43-2738-4dea-9ec3-887719ab3119',
#  'ebe855bd-8e35-4b3c-864b-7484788d6114',
#  '6a75555e-b4fc-4514-9344-f1e3a1c62ad4',
#  'ce12e713-7712-40f9-8990-927172622749',
#  'b65c2c22-1204-449c-b80c-ad04721cdea0',
#  'dd3aa272-7b7a-4b4a-9390-08afc9f1d64a',
#  'afbf7ccd-a902-4ccb-918e-fe9ba09f3af8',
#  '085221a8-b41b-4bad-b58e-e8da7069bc0e',
#  '50ab358e-8256-4db9-8002-87e92c6cbaf3',
#  '9a1cd42c-ba8d-43fd-928c-7048d28a1ec8',
#  '3fbe156b-f15b-4bf7-b3af-5e7f0bac70ba',
#  '09a663aa-0a38-47c4-88bf-0178a22ab4ba',
#  'f149f496-0908-4473-b85e-2872171e5458',
#  '648d220a-4d0d-4adf-9970-ef60a4f30f8a',
#  'fd20a949-77cd-4601-9974-61b6f3f57e6a',
#  'c3e45e8e-00df-44b4-87ea-b1b3b839fd9e',
#  '51a9e284-2a60-4556-9a6a-cdb0a828141f',
#  '4eb263f0-def9-4942-b22d-33b4e4c52082',
#  '9392cc84-5e6b-4695-90f0-7138dc20959d',
#  'd9d7fd5e-07e6-4b9f-8bd7-0c035e768aa4',
#  '7ce12c25-2d92-46f5-9d83-a78546ede7bf',
#  '5d69590d-05b0-441c-9187-89cadf7d0eaa',
#  '1e762e8a-bae3-4432-8120-37a74e3bee7d',
#  '4978e606-f66b-475f-8482-ae21719a9334',
#  '15bf8cf5-e253-4056-bb67-8192fff16ccd',
#  '6d4c0d57-ec9f-461b-8daf-b48fa2631877',
#  '56dd1c55-2172-443c-9b0d-c24e4690ea65',
#  'caaf706c-5037-40da-880d-218e51fad18e',
#  '2a58f545-19a8-4ff6-bc24-3459a9675fc0',
#  'd9b08e0a-b34d-4c9d-a160-ba17f161615d',
#  '5459e389-6172-442a-9c3d-36ac9d1f86e7',
#  '49d533b1-2344-4dcd-8de8-8deafec11863',
#  '0a8b7817-8237-4fb4-8a52-c67e6f85ade8',
#  '554540a1-35b5-422d-b108-b419ab2f63e7',
#  'ba0b11d5-df1e-44d3-899c-1f35a32a59e8',
#  '45d4b15a-4d6b-486e-81b3-fe537502740d',
#  'cef9e9ca-a4fd-41de-a60f-249e41c779b2',
#  'f6a4c3f2-1a35-4bed-9d75-81f31bb313cc',
#  'b26fec18-6a31-4e70-ba1d-c71c11847552',
#  '309c5de0-6bf0-4dbb-bdfb-22b49282fc6c',
#  'c6d11b46-86a7-415e-b0f3-335c702768b9',
#  'c6cc9c31-7723-4fe6-a400-d56d2fbf0688',
#  'acbab15a-a804-4887-8c2f-dae96018aa07',
#  '3d6b0ad4-8a25-4217-a306-e7a9019b68cf',
#  '295f5e2b-c839-4d84-968b-7f239dd44b1c',
#  '3b3c54b2-4206-4ab6-9373-730b2a0e6595',
#  'de6d8c0e-880a-4b44-94e3-5f76919dbb1b',
#  'f0e6ee98-e315-480a-a207-29aac80f4972',
#  'b2692da3-c110-4780-9044-38e0d3cee65b',
#  '991034c2-1221-411e-967c-8800d5efdc20',
#  '1e0850d0-1a4d-4447-9728-c87a5b6fcc83',
#  '5a73840a-a3be-4855-875c-a32b19cba7d8',
#  '72723a85-503e-47ea-8eef-b32736c0a6c9',
#  '8eaead69-bb0a-4f2b-9569-a18813aa5182',
#  'ffffb475-d2e5-4e39-b276-04db2cb24789',
#  '6216ed92-efcc-4987-a333-a557b677a964',
#  'fc2079e2-616f-4377-a43b-dfe1b4f87716',
#  'af264d92-92f0-4c3d-bf44-a0cc9fe8f547',
#  'ce5a5a95-4f40-4248-b56c-d108428f8ac6',
#  '6505a6bd-9d6e-4a0c-8da9-d65a552e8b38',
#  '02cc1e71-f2d0-4fda-b89e-52fc41fb5051',
#  'c6345d66-cd6a-4ca1-893e-ceda74a24ff8',
#  '3cdb512d-c1ad-4382-913f-1f9ea46bc7f1',
#  '0fbec4fd-3897-4ae3-a9d0-3db48893a05c',
#  'bed49ae6-29ba-49f8-894c-264f4d5a3b58',
#  '77cdabb1-93c1-419c-97f8-4935a6d30b71',
#  'a709cd89-7c83-4667-99fe-736a69210450']

# %%
vector_store.save_local("faiss_index")
